# %%
from UR10 import UR10, visualize
import numpy as np

from stable_baselines3 import PPO, DDPG
from gym.wrappers import FlattenObservation
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import StopTrainingOnNoModelImprovement, EvalCallback
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
import torch
# Out:
# pybullet build time: May  2 2023 06:19:30

# %%
def linear_schedule(initial_value: float):
    def func(progress_remaining: float) -> float:
        return progress_remaining * initial_value

    return func

# %%
angle_control=True
complex_obs_space=True
force = 0.1

env = FlattenObservation(UR10(
    is_dense=True, is_train=True, is_fixed=False, angle_control=angle_control, force=force, 
    complex_obs_space=complex_obs_space, complex_reward=False, pos_range=0.5
))
# Normalize

eval_env = FlattenObservation(UR10(
    is_dense=False, is_train=True, is_fixed=False, angle_control=angle_control, force=force, 
    complex_obs_space=complex_obs_space, pos_range=0.5
))

stop_train_callback = StopTrainingOnNoModelImprovement(max_no_improvement_evals=50, min_evals=200, verbose=1)
eval_callback = EvalCallback(eval_env, best_model_save_path='./models/bestmodels/',
                             n_eval_episodes=20, eval_freq=20000, callback_after_eval=stop_train_callback, 
                             deterministic=True, render=False, verbose=0)

'''vec_env = SubprocVecEnv(
    [lambda: FlattenObservation(UR10(is_train=True, is_fixed=False, angle_control=True, is_dense=True, force=0.1))] * 6
)'''

# default for PPO - 64
policy_kwargs = dict(activation_fn=torch.nn.ReLU, net_arch=dict(pi=[256, 256], vf=[256, 256]))
model = PPO(
    "MlpPolicy", env, verbose=0, tensorboard_log='./tesnsorboard_log/',
    policy_kwargs=policy_kwargs, learning_rate=0.0003
            # learning_rate=linear_schedule(0.0003)
           )

n_actions = env.action_space.shape[-1]
# action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.005 * np.ones(n_actions), dtype=np.float64)
action_noise = OrnsteinUhlenbeckActionNoise(mean=np.zeros(n_actions, dtype=np.float32), sigma=0.005 * np.ones(n_actions, dtype=np.float32))
model = DDPG("MlpPolicy", env, learning_rate=1e-4, batch_size=32, 
             action_noise=action_noise, tau=0.001, verbose=1, tensorboard_log='./tesnsorboard_log/')

model.learn(total_timesteps=2000000, progress_bar=True, callback=eval_callback)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 2023-06-20 21:53:32.209512: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Logging to ./tesnsorboard_log/DDPG_6
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -430     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 133      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | 1.59     |
# |    critic_loss     | 0.00223  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1500     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -458     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 128      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | 3.08     |
# |    critic_loss     | 0.00838  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3500     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -444     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 123      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | 4.14     |
# |    critic_loss     | 0.0262   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 5500     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -424     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 122      |
# |    time_elapsed    | 65       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 5.02     |
# |    critic_loss     | 0.0281   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 7500     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -399     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 122      |
# |    time_elapsed    | 81       |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | 5.81     |
# |    critic_loss     | 0.0432   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 9500     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -384     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 120      |
# |    time_elapsed    | 99       |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | 6.4      |
# |    critic_loss     | 0.059    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11500    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -374     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 119      |
# |    time_elapsed    | 116      |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | 7.15     |
# |    critic_loss     | 0.0503   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13500    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -367     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 118      |
# |    time_elapsed    | 135      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | 7.94     |
# |    critic_loss     | 0.0995   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15500    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -352     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 118      |
# |    time_elapsed    | 151      |
# |    total_timesteps | 18000    |
# | train/             |          |
# |    actor_loss      | 8.49     |
# |    critic_loss     | 0.115    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17500    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -344     |
# |    success_rate    | 0.025    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 119      |
# |    time_elapsed    | 167      |
# |    total_timesteps | 19996    |
# | train/             |          |
# |    actor_loss      | 9.16     |
# |    critic_loss     | 0.0904   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19500    |
# ---------------------------------
# /Users/dmitrijivanov/miniconda/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning:
# Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode
# lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor``
# wrapper.
#   warnings.warn(
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 472      |
# |    mean_reward     | -472     |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | 9.29     |
# |    critic_loss     | 0.128    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19996    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -342     |
# |    success_rate    | 0.0227   |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 114      |
# |    time_elapsed    | 192      |
# |    total_timesteps | 21996    |
# | train/             |          |
# |    actor_loss      | 9.8      |
# |    critic_loss     | 0.149    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21496    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -338     |
# |    success_rate    | 0.0208   |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 115      |
# |    time_elapsed    | 208      |
# |    total_timesteps | 23996    |
# | train/             |          |
# |    actor_loss      | 10.3     |
# |    critic_loss     | 0.224    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23496    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -338     |
# |    success_rate    | 0.0192   |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 116      |
# |    time_elapsed    | 223      |
# |    total_timesteps | 25996    |
# | train/             |          |
# |    actor_loss      | 10.9     |
# |    critic_loss     | 0.173    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 25496    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -335     |
# |    success_rate    | 0.0179   |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 116      |
# |    time_elapsed    | 239      |
# |    total_timesteps | 27996    |
# | train/             |          |
# |    actor_loss      | 11.5     |
# |    critic_loss     | 0.222    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 27496    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -332     |
# |    success_rate    | 0.0167   |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 117      |
# |    time_elapsed    | 255      |
# |    total_timesteps | 29996    |
# | train/             |          |
# |    actor_loss      | 12       |
# |    critic_loss     | 0.166    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 29496    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -330     |
# |    success_rate    | 0.0156   |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 117      |
# |    time_elapsed    | 272      |
# |    total_timesteps | 31996    |
# | train/             |          |
# |    actor_loss      | 12.4     |
# |    critic_loss     | 0.268    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 31496    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -327     |
# |    success_rate    | 0.0147   |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 118      |
# |    time_elapsed    | 288      |
# |    total_timesteps | 33996    |
# | train/             |          |
# |    actor_loss      | 12.9     |
# |    critic_loss     | 0.276    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33496    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -328     |
# |    success_rate    | 0.0139   |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 118      |
# |    time_elapsed    | 303      |
# |    total_timesteps | 35996    |
# | train/             |          |
# |    actor_loss      | 13.4     |
# |    critic_loss     | 0.221    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 35496    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -321     |
# |    success_rate    | 0.0125   |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 119      |
# |    time_elapsed    | 335      |
# |    total_timesteps | 39996    |
# | train/             |          |
# |    actor_loss      | 14.2     |
# |    critic_loss     | 0.344    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 39496    |
# ---------------------------------
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 495      |
# |    mean_reward     | -495     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | 14.2     |
# |    critic_loss     | 0.393    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 39996    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -323     |
# |    success_rate    | 0.0119   |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 116      |
# |    time_elapsed    | 360      |
# |    total_timesteps | 41996    |
# | train/             |          |
# |    actor_loss      | 14.5     |
# |    critic_loss     | 0.274    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 41496    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | -320     |
# |    success_rate    | 0.0227   |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 116      |
# |    time_elapsed    | 375      |
# |    total_timesteps | 43873    |
# | train/             |          |
# |    actor_loss      | 15.1     |
# |    critic_loss     | 0.246    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 43373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | -321     |
# |    success_rate    | 0.0217   |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 117      |
# |    time_elapsed    | 391      |
# |    total_timesteps | 45873    |
# | train/             |          |
# |    actor_loss      | 15.5     |
# |    critic_loss     | 0.313    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 45373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | -319     |
# |    success_rate    | 0.0208   |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 117      |
# |    time_elapsed    | 406      |
# |    total_timesteps | 47873    |
# | train/             |          |
# |    actor_loss      | 15.8     |
# |    critic_loss     | 0.259    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 47373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | -316     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 118      |
# |    time_elapsed    | 422      |
# |    total_timesteps | 49873    |
# | train/             |          |
# |    actor_loss      | 16.2     |
# |    critic_loss     | 0.358    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 49373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | -308     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 117      |
# |    time_elapsed    | 440      |
# |    total_timesteps | 51873    |
# | train/             |          |
# |    actor_loss      | 16.4     |
# |    critic_loss     | 0.543    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 51373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | -295     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 117      |
# |    time_elapsed    | 473      |
# |    total_timesteps | 55873    |
# | train/             |          |
# |    actor_loss      | 17       |
# |    critic_loss     | 0.425    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 55373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | -290     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 118      |
# |    time_elapsed    | 489      |
# |    total_timesteps | 57873    |
# | train/             |          |
# |    actor_loss      | 17.3     |
# |    critic_loss     | 0.677    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 57373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | -289     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 118      |
# |    time_elapsed    | 504      |
# |    total_timesteps | 59873    |
# | train/             |          |
# |    actor_loss      | 17.6     |
# |    critic_loss     | 0.512    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 59373    |
# ---------------------------------
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | -500     |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | 17.7     |
# |    critic_loss     | 0.523    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 59873    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | -286     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 116      |
# |    time_elapsed    | 530      |
# |    total_timesteps | 61873    |
# | train/             |          |
# |    actor_loss      | 17.9     |
# |    critic_loss     | 0.545    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 61373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | -286     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 116      |
# |    time_elapsed    | 547      |
# |    total_timesteps | 63873    |
# | train/             |          |
# |    actor_loss      | 18.2     |
# |    critic_loss     | 0.347    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 63373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | -284     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 117      |
# |    time_elapsed    | 562      |
# |    total_timesteps | 65873    |
# | train/             |          |
# |    actor_loss      | 18.4     |
# |    critic_loss     | 0.645    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 65373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | -285     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 117      |
# |    time_elapsed    | 579      |
# |    total_timesteps | 67873    |
# | train/             |          |
# |    actor_loss      | 18.7     |
# |    critic_loss     | 0.463    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 67373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | -284     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 116      |
# |    time_elapsed    | 598      |
# |    total_timesteps | 69873    |
# | train/             |          |
# |    actor_loss      | 19       |
# |    critic_loss     | 0.506    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 69373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | -283     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 116      |
# |    time_elapsed    | 615      |
# |    total_timesteps | 71873    |
# | train/             |          |
# |    actor_loss      | 19.1     |
# |    critic_loss     | 0.703    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 71373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 495      |
# |    ep_rew_mean     | -280     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 116      |
# |    time_elapsed    | 630      |
# |    total_timesteps | 73506    |
# | train/             |          |
# |    actor_loss      | 19.1     |
# |    critic_loss     | 0.403    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 73006    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 495      |
# |    ep_rew_mean     | -279     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 116      |
# |    time_elapsed    | 646      |
# |    total_timesteps | 75506    |
# | train/             |          |
# |    actor_loss      | 19.5     |
# |    critic_loss     | 0.381    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 75006    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 492      |
# |    ep_rew_mean     | -275     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 116      |
# |    time_elapsed    | 660      |
# |    total_timesteps | 77172    |
# | train/             |          |
# |    actor_loss      | 19.7     |
# |    critic_loss     | 0.364    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 76672    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 489      |
# |    ep_rew_mean     | -272     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 116      |
# |    time_elapsed    | 675      |
# |    total_timesteps | 78928    |
# | train/             |          |
# |    actor_loss      | 19.6     |
# |    critic_loss     | 0.781    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 78428    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 489      |
# |    ep_rew_mean     | -270     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 115      |
# |    time_elapsed    | 700      |
# |    total_timesteps | 80928    |
# | train/             |          |
# |    actor_loss      | 19.7     |
# |    critic_loss     | 0.812    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 80428    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 489      |
# |    ep_rew_mean     | -269     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 115      |
# |    time_elapsed    | 716      |
# |    total_timesteps | 82928    |
# | train/             |          |
# |    actor_loss      | 19.9     |
# |    critic_loss     | 0.52     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 82428    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 489      |
# |    ep_rew_mean     | -266     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 115      |
# |    time_elapsed    | 732      |
# |    total_timesteps | 84928    |
# | train/             |          |
# |    actor_loss      | 20       |
# |    critic_loss     | 0.609    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 84428    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 489      |
# |    ep_rew_mean     | -266     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 116      |
# |    time_elapsed    | 766      |
# |    total_timesteps | 88928    |
# | train/             |          |
# |    actor_loss      | 20.2     |
# |    critic_loss     | 0.565    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 88428    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 487      |
# |    ep_rew_mean     | -260     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 115      |
# |    time_elapsed    | 782      |
# |    total_timesteps | 90696    |
# | train/             |          |
# |    actor_loss      | 20.2     |
# |    critic_loss     | 0.623    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 90196    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 484      |
# |    ep_rew_mean     | -256     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 115      |
# |    time_elapsed    | 795      |
# |    total_timesteps | 92313    |
# | train/             |          |
# |    actor_loss      | 20.3     |
# |    critic_loss     | 0.454    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 91813    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 482      |
# |    ep_rew_mean     | -252     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 116      |
# |    time_elapsed    | 809      |
# |    total_timesteps | 94041    |
# | train/             |          |
# |    actor_loss      | 20.2     |
# |    critic_loss     | 0.731    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 93541    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 480      |
# |    ep_rew_mean     | -250     |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 116      |
# |    time_elapsed    | 826      |
# |    total_timesteps | 95856    |
# | train/             |          |
# |    actor_loss      | 20.2     |
# |    critic_loss     | 0.667    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 95356    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 477      |
# |    ep_rew_mean     | -249     |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 115      |
# |    time_elapsed    | 841      |
# |    total_timesteps | 97575    |
# | train/             |          |
# |    actor_loss      | 20.4     |
# |    critic_loss     | 0.647    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 97356    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 473      |
# |    ep_rew_mean     | -247     |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 116      |
# |    time_elapsed    | 852      |
# |    total_timesteps | 99215    |
# | train/             |          |
# |    actor_loss      | 20.3     |
# |    critic_loss     | 0.754    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 98715    |
# ---------------------------------
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 433      |
# |    mean_reward     | -433     |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | 20.3     |
# |    critic_loss     | 0.274    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 99734    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 464      |
# |    ep_rew_mean     | -239     |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 115      |
# |    time_elapsed    | 870      |
# |    total_timesteps | 100234   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 460      |
# |    ep_rew_mean     | -235     |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 115      |
# |    time_elapsed    | 883      |
# |    total_timesteps | 101907   |
# | train/             |          |
# |    actor_loss      | 20.1     |
# |    critic_loss     | 0.986    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 101407   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 455      |
# |    ep_rew_mean     | -230     |
# |    success_rate    | 0.15     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 114      |
# |    time_elapsed    | 899      |
# |    total_timesteps | 103363   |
# | train/             |          |
# |    actor_loss      | 20       |
# |    critic_loss     | 0.651    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 103198   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 451      |
# |    ep_rew_mean     | -227     |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 115      |
# |    time_elapsed    | 911      |
# |    total_timesteps | 105017   |
# | train/             |          |
# |    actor_loss      | 20       |
# |    critic_loss     | 0.53     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 104517   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 451      |
# |    ep_rew_mean     | -228     |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 115      |
# |    time_elapsed    | 928      |
# |    total_timesteps | 107017   |
# | train/             |          |
# |    actor_loss      | 20       |
# |    critic_loss     | 0.6      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 106517   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 451      |
# |    ep_rew_mean     | -226     |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 115      |
# |    time_elapsed    | 946      |
# |    total_timesteps | 109017   |
# | train/             |          |
# |    actor_loss      | 19.9     |
# |    critic_loss     | 0.557    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 108517   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 448      |
# |    ep_rew_mean     | -223     |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 115      |
# |    time_elapsed    | 961      |
# |    total_timesteps | 110662   |
# | train/             |          |
# |    actor_loss      | 20       |
# |    critic_loss     | 0.514    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 110162   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 448      |
# |    ep_rew_mean     | -221     |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 115      |
# |    time_elapsed    | 978      |
# |    total_timesteps | 112662   |
# | train/             |          |
# |    actor_loss      | 19.9     |
# |    critic_loss     | 0.447    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 112162   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 448      |
# |    ep_rew_mean     | -223     |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 115      |
# |    time_elapsed    | 996      |
# |    total_timesteps | 114662   |
# | train/             |          |
# |    actor_loss      | 19.8     |
# |    critic_loss     | 0.658    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 114162   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 441      |
# |    ep_rew_mean     | -217     |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 114      |
# |    time_elapsed    | 1009     |
# |    total_timesteps | 115990   |
# | train/             |          |
# |    actor_loss      | 19.8     |
# |    critic_loss     | 0.501    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 115814   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 441      |
# |    ep_rew_mean     | -218     |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 115      |
# |    time_elapsed    | 1021     |
# |    total_timesteps | 117643   |
# | train/             |          |
# |    actor_loss      | 19.7     |
# |    critic_loss     | 0.538    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 117143   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 441      |
# |    ep_rew_mean     | -216     |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 115      |
# |    time_elapsed    | 1038     |
# |    total_timesteps | 119643   |
# | train/             |          |
# |    actor_loss      | 19.8     |
# |    critic_loss     | 0.588    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 119143   |
# ---------------------------------
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 435      |
# |    mean_reward     | -435     |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 120000   |
# | train/             |          |
# |    actor_loss      | 19.7     |
# |    critic_loss     | 0.523    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 119771   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 437      |
# |    ep_rew_mean     | -212     |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 114      |
# |    time_elapsed    | 1057     |
# |    total_timesteps | 120907   |
# | train/             |          |
# |    actor_loss      | 19.9     |
# |    critic_loss     | 0.698    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 120407   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 440      |
# |    ep_rew_mean     | -212     |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 114      |
# |    time_elapsed    | 1072     |
# |    total_timesteps | 122907   |
# | train/             |          |
# |    actor_loss      | 19.5     |
# |    critic_loss     | 0.671    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 122407   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 429      |
# |    ep_rew_mean     | -205     |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 114      |
# |    time_elapsed    | 1080     |
# |    total_timesteps | 123831   |
# | train/             |          |
# |    actor_loss      | 19.6     |
# |    critic_loss     | 0.687    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 123331   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 422      |
# |    ep_rew_mean     | -202     |
# |    success_rate    | 0.24     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 114      |
# |    time_elapsed    | 1093     |
# |    total_timesteps | 125145   |
# | train/             |          |
# |    actor_loss      | 19.6     |
# |    critic_loss     | 0.505    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 125013   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 422      |
# |    ep_rew_mean     | -199     |
# |    success_rate    | 0.24     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 114      |
# |    time_elapsed    | 1106     |
# |    total_timesteps | 127145   |
# | train/             |          |
# |    actor_loss      | 19.3     |
# |    critic_loss     | 0.4      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 126645   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 422      |
# |    ep_rew_mean     | -197     |
# |    success_rate    | 0.24     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 115      |
# |    time_elapsed    | 1122     |
# |    total_timesteps | 129145   |
# | train/             |          |
# |    actor_loss      | 19.2     |
# |    critic_loss     | 0.653    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 128645   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 419      |
# |    ep_rew_mean     | -192     |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 114      |
# |    time_elapsed    | 1137     |
# |    total_timesteps | 130783   |
# | train/             |          |
# |    actor_loss      | 19.3     |
# |    critic_loss     | 0.726    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 130283   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 418      |
# |    ep_rew_mean     | -191     |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 115      |
# |    time_elapsed    | 1151     |
# |    total_timesteps | 132518   |
# | train/             |          |
# |    actor_loss      | 19.1     |
# |    critic_loss     | 0.512    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 132018   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 418      |
# |    ep_rew_mean     | -190     |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 115      |
# |    time_elapsed    | 1164     |
# |    total_timesteps | 134133   |
# | train/             |          |
# |    actor_loss      | 18.9     |
# |    critic_loss     | 0.317    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 133633   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 421      |
# |    ep_rew_mean     | -190     |
# |    success_rate    | 0.24     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 115      |
# |    time_elapsed    | 1181     |
# |    total_timesteps | 136133   |
# | train/             |          |
# |    actor_loss      | 18.9     |
# |    critic_loss     | 0.498    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 135633   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 420      |
# |    ep_rew_mean     | -188     |
# |    success_rate    | 0.24     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 115      |
# |    time_elapsed    | 1196     |
# |    total_timesteps | 137809   |
# | train/             |          |
# |    actor_loss      | 19       |
# |    critic_loss     | 0.335    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 137309   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 422      |
# |    ep_rew_mean     | -190     |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 115      |
# |    time_elapsed    | 1215     |
# |    total_timesteps | 139809   |
# | train/             |          |
# |    actor_loss      | 18.8     |
# |    critic_loss     | 0.55     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 139309   |
# ---------------------------------
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 484      |
# |    mean_reward     | -484     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    total_timesteps | 140000   |
# | train/             |          |
# |    actor_loss      | 18.9     |
# |    critic_loss     | 0.628    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 139809   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 426      |
# |    ep_rew_mean     | -192     |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 114      |
# |    time_elapsed    | 1243     |
# |    total_timesteps | 141809   |
# | train/             |          |
# |    actor_loss      | 18.7     |
# |    critic_loss     | 0.356    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 141309   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 433      |
# |    ep_rew_mean     | -198     |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 114      |
# |    time_elapsed    | 1272     |
# |    total_timesteps | 145161   |
# | train/             |          |
# |    actor_loss      | 18.5     |
# |    critic_loss     | 0.846    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 144661   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 438      |
# |    ep_rew_mean     | -202     |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 114      |
# |    time_elapsed    | 1290     |
# |    total_timesteps | 147161   |
# | train/             |          |
# |    actor_loss      | 18.5     |
# |    critic_loss     | 0.481    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 146661   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 438      |
# |    ep_rew_mean     | -202     |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 113      |
# |    time_elapsed    | 1305     |
# |    total_timesteps | 148823   |
# | train/             |          |
# |    actor_loss      | 18.3     |
# |    critic_loss     | 0.911    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 148323   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 431      |
# |    ep_rew_mean     | -198     |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 114      |
# |    time_elapsed    | 1317     |
# |    total_timesteps | 150163   |
# | train/             |          |
# |    actor_loss      | 18.4     |
# |    critic_loss     | 0.695    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 149663   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 428      |
# |    ep_rew_mean     | -196     |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 113      |
# |    time_elapsed    | 1334     |
# |    total_timesteps | 151838   |
# | train/             |          |
# |    actor_loss      | 18.3     |
# |    critic_loss     | 0.59     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 151663   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 432      |
# |    ep_rew_mean     | -198     |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 113      |
# |    time_elapsed    | 1350     |
# |    total_timesteps | 153838   |
# | train/             |          |
# |    actor_loss      | 18.4     |
# |    critic_loss     | 0.387    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 153338   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 429      |
# |    ep_rew_mean     | -196     |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 113      |
# |    time_elapsed    | 1365     |
# |    total_timesteps | 155602   |
# | train/             |          |
# |    actor_loss      | 18.2     |
# |    critic_loss     | 0.529    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 155102   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 420      |
# |    ep_rew_mean     | -189     |
# |    success_rate    | 0.24     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 113      |
# |    time_elapsed    | 1378     |
# |    total_timesteps | 156675   |
# | train/             |          |
# |    actor_loss      | 18.2     |
# |    critic_loss     | 0.574    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 156558   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 420      |
# |    ep_rew_mean     | -189     |
# |    success_rate    | 0.24     |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 113      |
# |    time_elapsed    | 1390     |
# |    total_timesteps | 158025   |
# | train/             |          |
# |    actor_loss      | 18.2     |
# |    critic_loss     | 0.317    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 157877   |
# ---------------------------------
# ---------------------------------
# ...
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 2120     |
# |    fps             | 100      |
# |    time_elapsed    | 6716     |
# |    total_timesteps | 676041   |
# | train/             |          |
# |    actor_loss      | 13.9     |
# |    critic_loss     | 0.629    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 675870   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | -71.6    |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 2124     |
# |    fps             | 100      |
# |    time_elapsed    | 6723     |
# |    total_timesteps | 676673   |
# | train/             |          |
# |    actor_loss      | 14       |
# |    critic_loss     | 0.227    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 676530   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | -72.5    |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 2128     |
# |    fps             | 100      |
# |    time_elapsed    | 6731     |
# |    total_timesteps | 677454   |
# | train/             |          |
# |    actor_loss      | 13.8     |
# |    critic_loss     | 0.163    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 677320   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 217      |
# |    ep_rew_mean     | -73.4    |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 2132     |
# |    fps             | 100      |
# |    time_elapsed    | 6744     |
# |    total_timesteps | 678752   |
# | train/             |          |
# |    actor_loss      | 13.6     |
# |    critic_loss     | 0.277    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 678604   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 217      |
# |    ep_rew_mean     | -74.2    |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 2136     |
# |    fps             | 100      |
# |    time_elapsed    | 6753     |
# |    total_timesteps | 679663   |
# | train/             |          |
# |    actor_loss      | 13.8     |
# |    critic_loss     | 0.236    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 679535   |
# ---------------------------------
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 322      |
# |    mean_reward     | -321     |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    total_timesteps | 680000   |
# | train/             |          |
# |    actor_loss      | 13.8     |
# |    critic_loss     | 0.343    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 679807   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 218      |
# |    ep_rew_mean     | -75.6    |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 2140     |
# |    fps             | 100      |
# |    time_elapsed    | 6775     |
# |    total_timesteps | 680637   |
# | train/             |          |
# |    actor_loss      | 13.8     |
# |    critic_loss     | 0.106    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 680481   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 219      |
# |    ep_rew_mean     | -76.1    |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 2144     |
# |    fps             | 100      |
# |    time_elapsed    | 6782     |
# |    total_timesteps | 681309   |
# | train/             |          |
# |    actor_loss      | 13.8     |
# |    critic_loss     | 0.0811   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 681107   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 225      |
# |    ep_rew_mean     | -78.7    |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 2148     |
# |    fps             | 100      |
# |    time_elapsed    | 6792     |
# |    total_timesteps | 682590   |
# | train/             |          |
# |    actor_loss      | 13.9     |
# |    critic_loss     | 0.19     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 682090   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | -77.5    |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 2152     |
# |    fps             | 100      |
# |    time_elapsed    | 6801     |
# |    total_timesteps | 683251   |
# | train/             |          |
# |    actor_loss      | 14.1     |
# |    critic_loss     | 0.194    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 683068   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | -78.5    |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 2156     |
# |    fps             | 100      |
# |    time_elapsed    | 6816     |
# |    total_timesteps | 684589   |
# | train/             |          |
# |    actor_loss      | 14.2     |
# |    critic_loss     | 0.42     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 684410   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | -79.7    |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 2160     |
# |    fps             | 100      |
# |    time_elapsed    | 6827     |
# |    total_timesteps | 685680   |
# | train/             |          |
# |    actor_loss      | 14       |
# |    critic_loss     | 0.179    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 685473   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | -79      |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 2164     |
# |    fps             | 100      |
# |    time_elapsed    | 6840     |
# |    total_timesteps | 686562   |
# | train/             |          |
# |    actor_loss      | 13.9     |
# |    critic_loss     | 0.44     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 686441   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | -79.1    |
# |    success_rate    | 0.82     |
# | time/              |          |
# |    episodes        | 2168     |
# |    fps             | 100      |
# |    time_elapsed    | 6851     |
# |    total_timesteps | 687499   |
# | train/             |          |
# |    actor_loss      | 14.1     |
# |    critic_loss     | 0.449    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 686999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 232      |
# |    ep_rew_mean     | -77.3    |
# |    success_rate    | 0.82     |
# | time/              |          |
# |    episodes        | 2172     |
# |    fps             | 100      |
# |    time_elapsed    | 6872     |
# |    total_timesteps | 688468   |
# | train/             |          |
# |    actor_loss      | 13.9     |
# |    critic_loss     | 0.335    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 688299   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 234      |
# |    ep_rew_mean     | -78.4    |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 2176     |
# |    fps             | 100      |
# |    time_elapsed    | 6883     |
# |    total_timesteps | 689407   |
# | train/             |          |
# |    actor_loss      | 14.2     |
# |    critic_loss     | 0.0991   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 688907   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 237      |
# |    ep_rew_mean     | -78.7    |
# |    success_rate    | 0.8      |
# | time/              |          |
# |    episodes        | 2180     |
# |    fps             | 100      |
# |    time_elapsed    | 6902     |
# |    total_timesteps | 690384   |
# | train/             |          |
# |    actor_loss      | 13.9     |
# |    critic_loss     | 0.218    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 690206   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | -77.1    |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 2184     |
# |    fps             | 99       |
# |    time_elapsed    | 6911     |
# |    total_timesteps | 691041   |
# | train/             |          |
# |    actor_loss      | 13.8     |
# |    critic_loss     | 0.255    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 690911   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | -78      |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 2188     |
# |    fps             | 99       |
# |    time_elapsed    | 6918     |
# |    total_timesteps | 691720   |
# | train/             |          |
# |    actor_loss      | 13.7     |
# |    critic_loss     | 0.119    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 691594   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | -76.3    |
# |    success_rate    | 0.82     |
# | time/              |          |
# |    episodes        | 2192     |
# |    fps             | 99       |
# |    time_elapsed    | 6924     |
# |    total_timesteps | 692247   |
# | train/             |          |
# |    actor_loss      | 13.8     |
# |    critic_loss     | 0.293    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 692114   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 223      |
# |    ep_rew_mean     | -75.3    |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 2196     |
# |    fps             | 99       |
# |    time_elapsed    | 6932     |
# |    total_timesteps | 692942   |
# | train/             |          |
# |    actor_loss      | 13.9     |
# |    critic_loss     | 0.329    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 692789   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -76.6    |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 99       |
# |    time_elapsed    | 6943     |
# |    total_timesteps | 693972   |
# | train/             |          |
# |    actor_loss      | 13.6     |
# |    critic_loss     | 0.0686   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 693849   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | -77.5    |
# |    success_rate    | 0.82     |
# | time/              |          |
# |    episodes        | 2204     |
# |    fps             | 99       |
# |    time_elapsed    | 6953     |
# |    total_timesteps | 695325   |
# | train/             |          |
# |    actor_loss      | 13.6     |
# |    critic_loss     | 0.539    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 694825   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -76.3    |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 2208     |
# |    fps             | 99       |
# |    time_elapsed    | 6966     |
# |    total_timesteps | 696239   |
# | train/             |          |
# |    actor_loss      | 14       |
# |    critic_loss     | 0.137    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 696071   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | -75.5    |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 2212     |
# |    fps             | 99       |
# |    time_elapsed    | 6972     |
# |    total_timesteps | 696788   |
# | train/             |          |
# |    actor_loss      | 13.6     |
# |    critic_loss     | 0.386    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 696664   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | -75.8    |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 2216     |
# |    fps             | 99       |
# |    time_elapsed    | 6983     |
# |    total_timesteps | 697935   |
# | train/             |          |
# |    actor_loss      | 13.7     |
# |    critic_loss     | 0.315    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 697631   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 232      |
# |    ep_rew_mean     | -78.7    |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 2220     |
# |    fps             | 99       |
# |    time_elapsed    | 6998     |
# |    total_timesteps | 699255   |
# | train/             |          |
# |    actor_loss      | 13.8     |
# |    critic_loss     | 0.187    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 699108   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | -79.4    |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 2224     |
# |    fps             | 99       |
# |    time_elapsed    | 7005     |
# |    total_timesteps | 699927   |
# | train/             |          |
# |    actor_loss      | 13.7     |
# |    critic_loss     | 0.376    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 699752   |
# ---------------------------------
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 170      |
# |    mean_reward     | -169     |
# |    success_rate    | 1        |
# | time/              |          |
# |    total_timesteps | 700000   |
# | train/             |          |
# |    actor_loss      | 13.8     |
# |    critic_loss     | 0.332    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 699927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | -78.5    |
# |    success_rate    | 0.81     |
# | time/              |          |
# |    episodes        | 2228     |
# |    fps             | 99       |
# |    time_elapsed    | 7020     |
# |    total_timesteps | 700550   |
# | train/             |          |
# |    actor_loss      | 13.7     |
# |    critic_loss     | 0.328    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 700407   |
# ---------------------------------

# %%
model.save("models/ddpg_ur10_1m.model")
